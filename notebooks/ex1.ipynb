# %%
import os
import sys
sys.path.append("..")
from src import AudioData

# %%
speech1_file = os.getcwd() + "/../Exercise1/AudioFiles/speech1.wav"
speech2_file = os.getcwd() + "/../Exercise1/AudioFiles/speech2.wav"
speech1 = AudioData(speech1_file)
speech2 = AudioData(speech2_file)
# Out:
# Successfully loaded audio data from file: /home/p0w3r/gitrepos/ssp20/notebooks/../Exercise1/AudioFiles/speech1.wav
# Successfully loaded audio data from file: /home/p0w3r/gitrepos/ssp20/notebooks/../Exercise1/AudioFiles/speech2.wav

# %%
speech1.play(2.3)

# %% [markdown]
# # Fundamental frequency estimation by eye

# %%
speech1.plot(2.3)

# %%
speech1.play(2.355, 2.545)

# %%
# estimated fundamental frequ for speech1.wav
1 / ((2.4191 - 2.3669) / 10)
# Out:
# 191.57088122605356

# %%
speech2.plot(0.375,0.530)

# %%
speech2.play(0.375,0.530)

# %%
# estimated fundamental frequ for speech2.wav
1 / ((0.4740 - 0.3865) / 10)
# Out:
# 114.28571428571432

# %% [markdown]
# # Block processing
# See AudioData::get_frames

# %% [markdown]
# # Fundamental Frequency Estimation

# %%
a = speech1.estimate_fundamental_freq(plot=True)

# %%
a = speech2.estimate_fundamental_freq(plot=True)
